# %%
"""
Environment initialization and repository setup.
Clones the project repository or pulls the latest updates,
installs dependencies, and configures the system path.
"""
import os
import sys

# Repository configuration
REPO_URL = "https://github.com/talspec2/red-string.git"
PROJECT_DIR = "red-string"

# Clone the repository if absent; otherwise, pull recent changes
if not os.path.exists(PROJECT_DIR):
    print(f"🚀 Cloning {PROJECT_DIR} from GitHub...")
    # !git clone $REPO_URL
else:
    print(f"🔄 Updating {PROJECT_DIR}...")
    # !cd $PROJECT_DIR && git pull

# Install required packages
print("📦 Installing dependencies from requirements.txt...")
# %pip install -r $PROJECT_DIR/requirements.txt -q

# Append project directory to system path for module imports
if os.path.abspath(PROJECT_DIR) not in sys.path:
    sys.path.append(os.path.abspath(PROJECT_DIR))

# %%
"""
Library imports and module dependencies required for training.
"""
from unsloth import is_bfloat16_supported
from datasets import Dataset
from trl import SFTTrainer
from transformers import TrainingArguments

from train_utils.config import SYSTEM_INSTRUCTION, MAX_SEQ_LENGTH
from train_utils.data_utils import process, prompt
from train_utils.model_utils import load_model

# %%
"""
Data ingestion and preprocessing.
Processes raw dataset records and converts them into a Hugging Face Dataset format.
"""
raw_data = process(SYSTEM_INSTRUCTION, amount=20000)
dataset = Dataset.from_list(raw_data)
print(f"✅ Data processed. {len(dataset)} examples ready.")

# %%
"""
Model instantiation.
Loads the base language model and applies parameter-efficient fine-tuning (PEFT) adapters.
"""
model, tokenizer = load_model()
print("✅ Model loaded and adapters attached.")

# %%
"""
Prompt formulation.
Maps the tokenized prompts across the dataset batch.
"""
dataset = dataset.map(lambda x: prompt(x, tokenizer), batched=True)

# %%
"""
Model training configuration and execution.
Initializes the SFTTrainer with specified hyperparameters and begins the training loop.
"""
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=MAX_SEQ_LENGTH,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=100,
        num_train_epochs=1,
        learning_rate=2e-4,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=10,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
    ),
)

print("Starting Training")
trainer.train()
print("Done!")

# %%
"""
Model serialization.
Saves the fine-tuned model and tokenizer to disk in GGUF format.
"""
save_path = "red-string-model"

# Quantization method specifies output precision ("q4_k_m" for efficiency, "q8_0" for accuracy)
trainer.model.save_pretrained_gguf(save_path, tokenizer, quantization_method="q8_0")

print(f"Model saved to {save_path}")

# %%
"""
Drive integration and export.
Mounts Google Drive and transfers the serialized model for persistent storage.
"""
from google.colab import drive
import shutil
import os

# Mount Google Drive
drive.mount("/content/drive")

# Define file transfer paths
source_path = "/content/red-string-model/meta-llama-3.1-8b.Q4_K_M.gguf"
destination_folder = "/content/drive/MyDrive/redstring/"

# Ensure the destination directory exists
os.makedirs(destination_folder, exist_ok=True)

# Execute file copy operation
print(f"Copying model to {destination_folder}...")
shutil.copy(source_path, destination_folder)
print("Done! Model copied to Google Drive.")
